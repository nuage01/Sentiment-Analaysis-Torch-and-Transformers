# %%
import urllib.request
from bs4 import BeautifulSoup
import requests
import logging
import sys
import urllib.request
import json
import time
import random

# %%
strr = """[{'Mozilla/5.0 (X11; Linux x86_64; rv:80.0) Gecko/20100101 Firefox/80.0'},
{'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246'},
{'Mozilla/5.0 (Windows Phone 10.0; Android 6.0.1; Microsoft; RM-1152) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Mobile Safari/537.36 Edge/15.15254'},
{'Mozilla/5.0 (iPhone; CPU iPhone OS 12_0 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) CriOS/69.0.3497.105 Mobile/15E148 Safari/605.1'},
{'Mozilla/5.0 (Linux; Android 8.0.0; SM-G960F Build/R16NW) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.84 Mobile Safari/537.36'},
{'Mozilla/5.0 (Linux; Android 7.0; SM-G892A Build/NRD90M; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/60.0.3112.107 Mobile Safari/537.36'},
{'Mozilla/5.0 (CrKey armv7l 1.5.16041) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/31.0.1650.0 Safari/537.36'},
{'Mozilla/5.0 (Windows Phone 10.0; Android 6.0.1; Microsoft; RM-1152) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Mobile Safari/537.36 Edge/15.15254'},
{'Mozilla/5.0 (Linux; Android 6.0.1; SGP771 Build/32.2.A.0.253; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/52.0.2743.98 Safari/537.36'},
{'Mozilla/5.0 (Linux; Android 5.0.2; SAMSUNG SM-T550 Build/LRX22G) AppleWebKit/537.36 (KHTML, like Gecko) SamsungBrowser/3.3 Chrome/38.0.2125.102 Safari/537.36'}]"""

import re

strr = re.sub('}', '', strr)
strr = re.sub('{', '', strr)
strr = re.sub('\n', '', strr)
strr
# Out:
# "['Mozilla/5.0 (X11; Linux x86_64; rv:80.0) Gecko/20100101 Firefox/80.0','Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246','Mozilla/5.0 (Windows Phone 10.0; Android 6.0.1; Microsoft; RM-1152) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Mobile Safari/537.36 Edge/15.15254','Mozilla/5.0 (iPhone; CPU iPhone OS 12_0 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) CriOS/69.0.3497.105 Mobile/15E148 Safari/605.1','Mozilla/5.0 (Linux; Android 8.0.0; SM-G960F Build/R16NW) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.84 Mobile Safari/537.36','Mozilla/5.0 (Linux; Android 7.0; SM-G892A Build/NRD90M; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/60.0.3112.107 Mobile Safari/537.36','Mozilla/5.0 (CrKey armv7l 1.5.16041) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/31.0.1650.0 Safari/537.36','Mozilla/5.0 (Windows Phone 10.0; Android 6.0.1; Microsoft; RM-1152) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Mobile Safari/537.36 Edge/15.15254','Mozilla/5.0 (Linux; Android 6.0.1; SGP771 Build/32.2.A.0.253; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/52.0.2743.98 Safari/537.36','Mozilla/5.0 (Linux; Android 5.0.2; SAMSUNG SM-T550 Build/LRX22G) AppleWebKit/537.36 (KHTML, like Gecko) SamsungBrowser/3.3 Chrome/38.0.2125.102 Safari/537.36']"

# %%
UA = ['Mozilla/5.0 (X11; Linux x86_64; rv:80.0) Gecko/20100101 Firefox/80.0','Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246','Mozilla/5.0 (Windows Phone 10.0; Android 6.0.1; Microsoft; RM-1152) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Mobile Safari/537.36 Edge/15.15254','Mozilla/5.0 (iPhone; CPU iPhone OS 12_0 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) CriOS/69.0.3497.105 Mobile/15E148 Safari/605.1','Mozilla/5.0 (Linux; Android 8.0.0; SM-G960F Build/R16NW) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.84 Mobile Safari/537.36','Mozilla/5.0 (Linux; Android 7.0; SM-G892A Build/NRD90M; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/60.0.3112.107 Mobile Safari/537.36','Mozilla/5.0 (CrKey armv7l 1.5.16041) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/31.0.1650.0 Safari/537.36','Mozilla/5.0 (Windows Phone 10.0; Android 6.0.1; Microsoft; RM-1152) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Mobile Safari/537.36 Edge/15.15254','Mozilla/5.0 (Linux; Android 6.0.1; SGP771 Build/32.2.A.0.253; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/52.0.2743.98 Safari/537.36','Mozilla/5.0 (Linux; Android 5.0.2; SAMSUNG SM-T550 Build/LRX22G) AppleWebKit/537.36 (KHTML, like Gecko) SamsungBrowser/3.3 Chrome/38.0.2125.102 Safari/537.36']
host = "api.sofascore.com"
referer = "https://www.sofascore.com/tournament/football/europe/uefa-champions-league/7"
origin = "https://www.sofascore.com/"

s =requests.Session()
s.headers.update({"User-Agent": random.choice(UA)}) 
s.headers.update({'referer': referer})
s.headers.update({'host': host})
s.headers.update({'origin': origin})
s.headers
# Out:
# {'User-Agent': 'Mozilla/5.0 (Linux; Android 5.0.2; SAMSUNG SM-T550 Build/LRX22G) AppleWebKit/537.36 (KHTML, like Gecko) SamsungBrowser/3.3 Chrome/38.0.2125.102 Safari/537.36', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive', 'referer': 'https://www.sofascore.com/tournament/football/europe/uefa-champions-league/7', 'host': 'api.sofascore.com', 'origin': 'https://www.sofascore.com/'}

# %%
api = 'https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&group=summary'

# %%
pages = None
data_list = []
r = s.get(api)
if r.status_code==200:
    data = json.loads(r.text)
    data_list.append(data)
    pages = data['pages']
    
print(pages)
# Out:
# 36

# %%
data_list
# Out:
# [{'page': 1,
#   'pages': 36,
#   'results': [{'accuratePassesPercentage': 90.91,
#     'assists': 0,
#     'goals': 0,
#     'player': {'id': 976364,
#      'name': 'Ruslan Neshcheret',
#      'slug': 'ruslan-neshcheret',
#      'userCount': 671},
#     'rating': 9.7,
#     'successfulDribbles': 0,
#     'tackles': 0,
#     'team': {'id': 3305,
#      'slug': 'dynamo-kyiv',
#      'teamColors': {'primary': '#52b030',
#       'secondary': '#52b030',
#       'text': '#ffffff'},
#      'type': 0,
#      'userCount': 0}},
#    {'accuratePassesPercentage': 85.71,
#     'assists': 0,
#     'goals': 0,
#     'player': {'id': 2069,
#      'name': 'Gianluigi Buffon',
#      'slug': 'gianluigi-buffon',
#      'userCount': 11449},
#     'rating': 8.5,
#     'successfulDribbles': 0,
#     'tackles': 0,
#     'team': {'id': 2687,
#      'slug': 'juventus',
#      'teamColors': {'primary': '#52b030',
#       'secondary': '#52b030',
#       'text': '#ffffff'},
#      'type': 0,
#      'userCount': 0}},
#    {'accuratePassesPercentage': 87.25,
#     'assists': 3,
#     'goals': 1,
#     'player': {'id': 259117,
#      'name': 'Joshua Kimmich',
#      'slug': 'joshua-kimmich',
#      'userCount': 10321},
#     'rating': 8.47,
#     'successfulDribbles': 2,
#     'tackles': 9,
#     'team': {'id': 2672,
#      'slug': 'bayern-munchen',
#      'teamColors': {'primary': '#52b030',
#       'secondary': '#52b030',
#       'text': '#ffffff'},
#      'type': 0,
#      'userCount': 0}},
#    {'accuratePassesPercentage': 89.38,
#     'assists': 2,
#     'goals': 3,
#     'player': {'id': 12994,
#      'name': 'Lionel Messi',
#      'slug': 'lionel-messi',
#      'userCount': 301771},
#     'rating': 8.45,
#     'successfulDribbles': 23,
#     'tackles': 3,
#     'team': {'id': 2817,
#      'slug': 'barcelona',
#      'teamColors': {'primary': '#52b030',
#       'secondary': '#52b030',
#       'text': '#ffffff'},
#      'type': 0,
#      'userCount': 0}},
#    {'accuratePassesPercentage': 85,
#     'assists': 4,
#     'goals': 0,
#     'player': {'id': 70996,
#      'name': 'Kevin De Bruyne',
#      'slug': 'kevin-de-bruyne',
#      'userCount': 68347},
#     'rating': 8.4,
#     'successfulDribbles': 1,
#     'tackles': 5,
#     'team': {'id': 17,
#      'slug': 'manchester-city',
#      'teamColors': {'primary': '#52b030',
#       'secondary': '#52b030',
#       'text': '#ffffff'},
#      'type': 0,
#      'userCount': 0}},
#    {'accuratePassesPercentage': 81.44,
#     'assists': 0,
#     'goals': 6,
#     'player': {'id': 124712,
#      'name': 'Neymar',
#      'slug': 'neymar',
#      'userCount': 180587},
#     'rating': 8.08,
#     'successfulDribbles': 21,
#     'tackles': 3,
#     'team': {'id': 1644,
#      'slug': 'paris-saint-germain',
#      'teamColors': {'primary': '#52b030',
#       'secondary': '#52b030',
#       'text': '#ffffff'},
#      'type': 0,
#      'userCount': 0}},
#    {'accuratePassesPercentage': 74.63,
#     'assists': 0,
#     'goals': 6,
#     'player': {'id': 839956,
#      'name': 'Erling Braut Haaland',
#      'slug': 'erling-braut-haaland',
#      'userCount': 70181},
#     'rating': 8.08,
#     'successfulDribbles': 6,
#     'tackles': 0,
#     'team': {'id': 2673,
#      'slug': 'borussia-dortmund',
#      'teamColors': {'primary': '#52b030',
#       'secondary': '#52b030',
#       'text': '#ffffff'},
#      'type': 0,
#      'userCount': 0}},
#    {'accuratePassesPercentage': 81.13,
#     'assists': 1,
#     'goals': 5,
#     'player': {'id': 45923,
#      'name': 'Ciro Immobile',
#      'slug': 'ciro-immobile',
#      'userCount': 14734},
#     'rating': 7.98,
#     'successfulDribbles': 4,
#     'tackles': 1,
#     'team': {'id': 2699,
#      'slug': 'lazio',
#      'teamColors': {'primary': '#52b030',
#       'secondary': '#52b030',
#       'text': '#ffffff'},
#      'type': 0,
#      'userCount': 0}},
#    {'accuratePassesPercentage': 72.52,
#     'assists': 1,
#     'goals': 6,
#     'player': {'id': 125407,
#      'name': 'Álvaro Morata',
#      'slug': 'alvaro-morata',
#      'userCount': 14787},
#     'rating': 7.92,
#     'successfulDribbles': 9,
#     'tackles': 4,
#     'team': {'id': 2687,
#      'slug': 'juventus',
#      'teamColors': {'primary': '#52b030',
#       'secondary': '#52b030',
#       'text': '#ffffff'},
#      'type': 0,
#      'userCount': 0}},
#    {'accuratePassesPercentage': 85.71,
#     'assists': 0,
#     'goals': 0,
#     'player': {'id': 8959,
#      'name': 'Manuel Neuer',
#      'slug': 'manuel-neuer',
#      'userCount': 14516},
#     'rating': 7.84,
#     'successfulDribbles': 0,
#     'tackles': 0,
#     'team': {'id': 2672,
#      'slug': 'bayern-munchen',
#      'teamColors': {'primary': '#52b030',
#       'secondary': '#52b030',
#       'text': '#ffffff'},
#      'type': 0,
#      'userCount': 0}},
#    {'accuratePassesPercentage': 85.34,
#     'assists': 1,
#     'goals': 0,
#     'player': {'id': 84854,
#      'name': 'Alex Sandro',
#      'slug': 'alex-sandro',
#      'userCount': 5886},
#     'rating': 7.83,
#     'successfulDribbles': 5,
#     'tackles': 9,
#     'team': {'id': 2687,
#      'slug': 'juventus',
#      'teamColors': {'primary': '#52b030',
#       'secondary': '#52b030',
#       'text': '#ffffff'},
#      'type': 0,
#      'userCount': 0}},
#    {'accuratePassesPercentage': 73.97,
#     'assists': 1,
#     'goals': 4,
#     'player': {'id': 288205,
#      'name': 'Bruno Fernandes',
#      'slug': 'bruno-fernandes',
#      'userCount': 44331},
#     'rating': 7.8,
#     'successfulDribbles': 3,
#     'tackles': 9,
#     'team': {'id': 35,
#      'slug': 'manchester-united',
#      'teamColors': {'primary': '#52b030',
#       'secondary': '#52b030',
#       'text': '#ffffff'},
#      'type': 0,
#      'userCount': 0}},
#    {'accuratePassesPercentage': 62.07,
#     'assists': 0,
#     'goals': 0,
#     'player': {'id': 50539,
#      'name': 'Adrián',
#      'slug': 'adrian',
#      'userCount': 1877},
#     'rating': 7.8,
#     'successfulDribbles': 0,
#     'tackles': 0,
#     'team': {'id': 44,
#      'slug': 'liverpool',
#      'teamColors': {'primary': '#52b030',
#       'secondary': '#52b030',
#       'text': '#ffffff'},
#      'type': 0,
#      'userCount': 0}},
#    {'accuratePassesPercentage': 84.51,
#     'assists': 1,
#     'goals': 1,
#     'player': {'id': 829932,
#      'name': 'Cristian Romero',
#      'slug': 'cristian-romero',
#      'userCount': 1562},
#     'rating': 7.78,
#     'successfulDribbles': 1,
#     'tackles': 12,
#     'team': {'id': 2686,
#      'slug': 'atalanta',
#      'teamColors': {'primary': '#52b030',
#       'secondary': '#52b030',
#       'text': '#ffffff'},
#      'type': 0,
#      'userCount': 0}},
#    {'accuratePassesPercentage': 83.52,
#     'assists': 1,
#     'goals': 0,
#     'player': {'id': 578560,
#      'name': 'Marcos Acuña',
#      'slug': 'marcos-acuna',
#      'userCount': 1208},
#     'rating': 7.7,
#     'successfulDribbles': 7,
#     'tackles': 7,
#     'team': {'id': 2833,
#      'slug': 'sevilla',
#      'teamColors': {'primary': '#52b030',
#       'secondary': '#52b030',
#       'text': '#ffffff'},
#      'type': 0,
#      'userCount': 0}},
#    {'accuratePassesPercentage': 83.06,
#     'assists': 2,
#     'goals': 3,
#     'player': {'id': 818244,
#      'name': 'Ousmane Dembélé',
#      'slug': 'ousmane-dembele',
#      'userCount': 44118},
#     'rating': 7.68,
#     'successfulDribbles': 16,
#     'tackles': 2,
#     'team': {'id': 2817,
#      'slug': 'barcelona',
#      'teamColors': {'primary': '#52b030',
#       'secondary': '#52b030',
#       'text': '#ffffff'},
#      'type': 0,
#      'userCount': 0}},
#    {'accuratePassesPercentage': 86.14,
#     'assists': 1,
#     'goals': 0,
#     'player': {'id': 885908,
#      'name': 'Reece James',
#      'slug': 'reece-james',
#      'userCount': 5302},
#     'rating': 7.65,
#     'successfulDribbles': 1,
#     'tackles': 7,
#     'team': {'id': 38,
#      'slug': 'chelsea',
#      'teamColors': {'primary': '#52b030',
#       'secondary': '#52b030',
#       'text': '#ffffff'},
#      'type': 0,
#      'userCount': 0}},
#    {'accuratePassesPercentage': 67.09,
#     'assists': 0,
#     'goals': 0,
#     'player': {'id': 827362,
#      'name': 'Caoimhin Kelleher',
#      'slug': 'caoimhin-kelleher',
#      'userCount': 1226},
#     'rating': 7.65,
#     'successfulDribbles': 0,
#     'tackles': 0,
#     'team': {'id': 44,
#      'slug': 'liverpool',
#      'teamColors': {'primary': '#52b030',
#       'secondary': '#52b030',
#       'text': '#ffffff'},
#      'type': 0,
#      'userCount': 0}},
#    {'accuratePassesPercentage': 77.37,
#     'assists': 3,
#     'goals': 5,
#     'player': {'id': 192308,
#      'name': 'Alassane Pléa',
#      'slug': 'alassane-plea',
#      'userCount': 2887},
#     'rating': 7.63,
#     'successfulDribbles': 4,
#     'tackles': 2,
#     'team': {'id': 2527,
#      'slug': 'borussia-mgladbach',
#      'teamColors': {'primary': '#52b030',
#       'secondary': '#52b030',
#       'text': '#ffffff'},
#      'type': 0,
#      'userCount': 0}},
#    {'accuratePassesPercentage': 94.04,
#     'assists': 1,
#     'goals': 0,
#     'player': {'id': 26502,
#      'name': 'Toni Kroos',
#      'slug': 'toni-kroos',
#      'userCount': 35425},
#     'rating': 7.63,
#     'successfulDribbles': 1,
#     'tackles': 7,
#     'team': {'id': 2829,
#      'slug': 'real-madrid',
#      'teamColors': {'primary': '#52b030',
#       'secondary': '#52b030',
#       'text': '#ffffff'},
#      'type': 0,
#      'userCount': 0}}]}]

# %%
offset = 0

for i in range(0, pages):
    offset += 20
    api = f'https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset={offset}&group=summary'
    s.headers.update({"User-Agent": random.choice(UA)}) 
    r = s.get(api)
    print(api, r.status_code)
    d = json.loads(r.text)
    data_list.append(d)
    time.sleep(5)
# Out:
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=20&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=40&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=60&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=80&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=100&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=120&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=140&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=160&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=180&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=200&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=220&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=240&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=260&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=280&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=300&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=320&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=340&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=360&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=380&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=400&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=420&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=440&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=460&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=480&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=500&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=520&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=540&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=560&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=580&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=600&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=620&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=640&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=660&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=680&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=700&group=summary 200
# https://api.sofascore.com/api/v1/unique-tournament/7/season/29267/statistics?limit=20&order=-rating&offset=720&group=summary 200

# %%
data.update({'accuratePassesPercentage': 89.38,
   'assists': 2,
   'goals': 3,
   'player': {'id': 12994,
    'name': 'Lionel Messi',
    'slug': 'lionel-messi',
    'userCount': 301771},
   'rating': 8.45,
   'successfulDribbles': 23,
   'tackles': 3,
   'team': {'id': 2817,
    'slug': 'barcelona',
    'teamColors': {'primary': '#52b030',
     'secondary': '#52b030',
     'text': '#ffffff'},
    'type': 0,
    'userCount': 10000}},)

# %%
del(data)
data={}

# %%
dict_1 = {"a": 1, "b": 2}
dict_3 = {"c": 6, "d": 4}
dict_2 = {"c": 3, "d": 4}

# %%
dict_1.update(dict_3)

# %%
len(data_list)
# Out:
# 37

# %%
quardu = data_list[0]

# %%
infos = quardu

# %%
quardu
# Out:
# {'page': 1,
#  'pages': 36,
#  'results': [{'accuratePassesPercentage': 90.91,
#    'assists': 0,
#    'goals': 0,
#    'player': {'id': 976364,
#     'name': 'Ruslan Neshcheret',
#     'slug': 'ruslan-neshcheret',
#     'userCount': 671},
#    'rating': 9.7,
#    'successfulDribbles': 0,
#    'tackles': 0,
#    'team': {'id': 3305,
#     'slug': 'dynamo-kyiv',
#     'teamColors': {'primary': '#52b030',
#      'secondary': '#52b030',
#      'text': '#ffffff'},
#     'type': 0,
#     'userCount': 0}},
#   {'accuratePassesPercentage': 85.71,
#    'assists': 0,
#    'goals': 0,
#    'player': {'id': 2069,
#     'name': 'Gianluigi Buffon',
#     'slug': 'gianluigi-buffon',
#     'userCount': 11449},
#    'rating': 8.5,
#    'successfulDribbles': 0,
#    'tackles': 0,
#    'team': {'id': 2687,
#     'slug': 'juventus',
#     'teamColors': {'primary': '#52b030',
#      'secondary': '#52b030',
#      'text': '#ffffff'},
#     'type': 0,
#     'userCount': 0}},
#   {'accuratePassesPercentage': 87.25,
#    'assists': 3,
#    'goals': 1,
#    'player': {'id': 259117,
#     'name': 'Joshua Kimmich',
#     'slug': 'joshua-kimmich',
#     'userCount': 10321},
#    'rating': 8.47,
#    'successfulDribbles': 2,
#    'tackles': 9,
#    'team': {'id': 2672,
#     'slug': 'bayern-munchen',
#     'teamColors': {'primary': '#52b030',
#      'secondary': '#52b030',
#      'text': '#ffffff'},
#     'type': 0,
#     'userCount': 0}},
#   {'accuratePassesPercentage': 89.38,
#    'assists': 2,
#    'goals': 3,
#    'player': {'id': 12994,
#     'name': 'Lionel Messi',
#     'slug': 'lionel-messi',
#     'userCount': 301771},
#    'rating': 8.45,
#    'successfulDribbles': 23,
#    'tackles': 3,
#    'team': {'id': 2817,
#     'slug': 'barcelona',
#     'teamColors': {'primary': '#52b030',
#      'secondary': '#52b030',
#      'text': '#ffffff'},
#     'type': 0,
#     'userCount': 0}},
#   {'accuratePassesPercentage': 85,
#    'assists': 4,
#    'goals': 0,
#    'player': {'id': 70996,
#     'name': 'Kevin De Bruyne',
#     'slug': 'kevin-de-bruyne',
#     'userCount': 68347},
#    'rating': 8.4,
#    'successfulDribbles': 1,
#    'tackles': 5,
#    'team': {'id': 17,
#     'slug': 'manchester-city',
#     'teamColors': {'primary': '#52b030',
#      'secondary': '#52b030',
#      'text': '#ffffff'},
#     'type': 0,
#     'userCount': 0}},
#   {'accuratePassesPercentage': 81.44,
#    'assists': 0,
#    'goals': 6,
#    'player': {'id': 124712,
#     'name': 'Neymar',
#     'slug': 'neymar',
#     'userCount': 180587},
#    'rating': 8.08,
#    'successfulDribbles': 21,
#    'tackles': 3,
#    'team': {'id': 1644,
#     'slug': 'paris-saint-germain',
#     'teamColors': {'primary': '#52b030',
#      'secondary': '#52b030',
#      'text': '#ffffff'},
#     'type': 0,
#     'userCount': 0}},
#   {'accuratePassesPercentage': 74.63,
#    'assists': 0,
#    'goals': 6,
#    'player': {'id': 839956,
#     'name': 'Erling Braut Haaland',
#     'slug': 'erling-braut-haaland',
#     'userCount': 70181},
#    'rating': 8.08,
#    'successfulDribbles': 6,
#    'tackles': 0,
#    'team': {'id': 2673,
#     'slug': 'borussia-dortmund',
#     'teamColors': {'primary': '#52b030',
#      'secondary': '#52b030',
#      'text': '#ffffff'},
#     'type': 0,
#     'userCount': 0}},
#   {'accuratePassesPercentage': 81.13,
#    'assists': 1,
#    'goals': 5,
#    'player': {'id': 45923,
#     'name': 'Ciro Immobile',
#     'slug': 'ciro-immobile',
#     'userCount': 14734},
#    'rating': 7.98,
#    'successfulDribbles': 4,
#    'tackles': 1,
#    'team': {'id': 2699,
#     'slug': 'lazio',
#     'teamColors': {'primary': '#52b030',
#      'secondary': '#52b030',
#      'text': '#ffffff'},
#     'type': 0,
#     'userCount': 0}},
#   {'accuratePassesPercentage': 72.52,
#    'assists': 1,
#    'goals': 6,
#    'player': {'id': 125407,
#     'name': 'Álvaro Morata',
#     'slug': 'alvaro-morata',
#     'userCount': 14787},
#    'rating': 7.92,
#    'successfulDribbles': 9,
#    'tackles': 4,
#    'team': {'id': 2687,
#     'slug': 'juventus',
#     'teamColors': {'primary': '#52b030',
#      'secondary': '#52b030',
#      'text': '#ffffff'},
#     'type': 0,
#     'userCount': 0}},
#   {'accuratePassesPercentage': 85.71,
#    'assists': 0,
#    'goals': 0,
#    'player': {'id': 8959,
#     'name': 'Manuel Neuer',
#     'slug': 'manuel-neuer',
#     'userCount': 14516},
#    'rating': 7.84,
#    'successfulDribbles': 0,
#    'tackles': 0,
#    'team': {'id': 2672,
#     'slug': 'bayern-munchen',
#     'teamColors': {'primary': '#52b030',
#      'secondary': '#52b030',
#      'text': '#ffffff'},
#     'type': 0,
#     'userCount': 0}},
#   {'accuratePassesPercentage': 85.34,
#    'assists': 1,
#    'goals': 0,
#    'player': {'id': 84854,
#     'name': 'Alex Sandro',
#     'slug': 'alex-sandro',
#     'userCount': 5886},
#    'rating': 7.83,
#    'successfulDribbles': 5,
#    'tackles': 9,
#    'team': {'id': 2687,
#     'slug': 'juventus',
#     'teamColors': {'primary': '#52b030',
#      'secondary': '#52b030',
#      'text': '#ffffff'},
#     'type': 0,
#     'userCount': 0}},
#   {'accuratePassesPercentage': 73.97,
#    'assists': 1,
#    'goals': 4,
#    'player': {'id': 288205,
#     'name': 'Bruno Fernandes',
#     'slug': 'bruno-fernandes',
#     'userCount': 44331},
#    'rating': 7.8,
#    'successfulDribbles': 3,
#    'tackles': 9,
#    'team': {'id': 35,
#     'slug': 'manchester-united',
#     'teamColors': {'primary': '#52b030',
#      'secondary': '#52b030',
#      'text': '#ffffff'},
#     'type': 0,
#     'userCount': 0}},
#   {'accuratePassesPercentage': 62.07,
#    'assists': 0,
#    'goals': 0,
#    'player': {'id': 50539,
#     'name': 'Adrián',
#     'slug': 'adrian',
#     'userCount': 1877},
#    'rating': 7.8,
#    'successfulDribbles': 0,
#    'tackles': 0,
#    'team': {'id': 44,
#     'slug': 'liverpool',
#     'teamColors': {'primary': '#52b030',
#      'secondary': '#52b030',
#      'text': '#ffffff'},
#     'type': 0,
#     'userCount': 0}},
#   {'accuratePassesPercentage': 84.51,
#    'assists': 1,
#    'goals': 1,
#    'player': {'id': 829932,
#     'name': 'Cristian Romero',
#     'slug': 'cristian-romero',
#     'userCount': 1562},
#    'rating': 7.78,
#    'successfulDribbles': 1,
#    'tackles': 12,
#    'team': {'id': 2686,
#     'slug': 'atalanta',
#     'teamColors': {'primary': '#52b030',
#      'secondary': '#52b030',
#      'text': '#ffffff'},
#     'type': 0,
#     'userCount': 0}},
#   {'accuratePassesPercentage': 83.52,
#    'assists': 1,
#    'goals': 0,
#    'player': {'id': 578560,
#     'name': 'Marcos Acuña',
#     'slug': 'marcos-acuna',
#     'userCount': 1208},
#    'rating': 7.7,
#    'successfulDribbles': 7,
#    'tackles': 7,
#    'team': {'id': 2833,
#     'slug': 'sevilla',
#     'teamColors': {'primary': '#52b030',
#      'secondary': '#52b030',
#      'text': '#ffffff'},
#     'type': 0,
#     'userCount': 0}},
#   {'accuratePassesPercentage': 83.06,
#    'assists': 2,
#    'goals': 3,
#    'player': {'id': 818244,
#     'name': 'Ousmane Dembélé',
#     'slug': 'ousmane-dembele',
#     'userCount': 44118},
#    'rating': 7.68,
#    'successfulDribbles': 16,
#    'tackles': 2,
#    'team': {'id': 2817,
#     'slug': 'barcelona',
#     'teamColors': {'primary': '#52b030',
#      'secondary': '#52b030',
#      'text': '#ffffff'},
#     'type': 0,
#     'userCount': 0}},
#   {'accuratePassesPercentage': 86.14,
#    'assists': 1,
#    'goals': 0,
#    'player': {'id': 885908,
#     'name': 'Reece James',
#     'slug': 'reece-james',
#     'userCount': 5302},
#    'rating': 7.65,
#    'successfulDribbles': 1,
#    'tackles': 7,
#    'team': {'id': 38,
#     'slug': 'chelsea',
#     'teamColors': {'primary': '#52b030',
#      'secondary': '#52b030',
#      'text': '#ffffff'},
#     'type': 0,
#     'userCount': 0}},
#   {'accuratePassesPercentage': 67.09,
#    'assists': 0,
#    'goals': 0,
#    'player': {'id': 827362,
#     'name': 'Caoimhin Kelleher',
#     'slug': 'caoimhin-kelleher',
#     'userCount': 1226},
#    'rating': 7.65,
#    'successfulDribbles': 0,
#    'tackles': 0,
#    'team': {'id': 44,
#     'slug': 'liverpool',
#     'teamColors': {'primary': '#52b030',
#      'secondary': '#52b030',
#      'text': '#ffffff'},
#     'type': 0,
#     'userCount': 0}},
#   {'accuratePassesPercentage': 77.37,
#    'assists': 3,
#    'goals': 5,
#    'player': {'id': 192308,
#     'name': 'Alassane Pléa',
#     'slug': 'alassane-plea',
#     'userCount': 2887},
#    'rating': 7.63,
#    'successfulDribbles': 4,
#    'tackles': 2,
#    'team': {'id': 2527,
#     'slug': 'borussia-mgladbach',
#     'teamColors': {'primary': '#52b030',
#      'secondary': '#52b030',
#      'text': '#ffffff'},
#     'type': 0,
#     'userCount': 0}},
#   {'accuratePassesPercentage': 94.04,
#    'assists': 1,
#    'goals': 0,
#    'player': {'id': 26502,
#     'name': 'Toni Kroos',
#     'slug': 'toni-kroos',
#     'userCount': 35425},
#    'rating': 7.63,
#    'successfulDribbles': 1,
#    'tackles': 7,
#    'team': {'id': 2829,
#     'slug': 'real-madrid',
#     'teamColors': {'primary': '#52b030',
#      'secondary': '#52b030',
#      'text': '#ffffff'},
#     'type': 0,
#     'userCount': 0}}]}

# %%
results = quardu['results']

# %%
players_stats = {}
for player in results:
    p_id = player['player']['id']
    players_stats['id'] = p_id
    players_stats[p_id] = {}
    players_stats[p_id]['name'] = player['player']['name']
    players_stats[p_id]['club'] =player['team']['slug']
    players_stats[p_id]['rating'] =player['rating']

# %%
players_stats
# Out:
# {124712: {'club': 'paris-saint-germain', 'name': 'Neymar', 'rating': 8.08},
#  125407: {'club': 'juventus', 'name': 'Álvaro Morata', 'rating': 7.92},
#  12994: {'club': 'barcelona', 'name': 'Lionel Messi', 'rating': 8.45},
#  192308: {'club': 'borussia-mgladbach',
#   'name': 'Alassane Pléa',
#   'rating': 7.63},
#  2069: {'club': 'juventus', 'name': 'Gianluigi Buffon', 'rating': 8.5},
#  259117: {'club': 'bayern-munchen', 'name': 'Joshua Kimmich', 'rating': 8.47},
#  26502: {'club': 'real-madrid', 'name': 'Toni Kroos', 'rating': 7.63},
#  288205: {'club': 'manchester-united',
#   'name': 'Bruno Fernandes',
#   'rating': 7.8},
#  45923: {'club': 'lazio', 'name': 'Ciro Immobile', 'rating': 7.98},
#  50539: {'club': 'liverpool', 'name': 'Adrián', 'rating': 7.8},
#  578560: {'club': 'sevilla', 'name': 'Marcos Acuña', 'rating': 7.7},
#  70996: {'club': 'manchester-city', 'name': 'Kevin De Bruyne', 'rating': 8.4},
#  818244: {'club': 'barcelona', 'name': 'Ousmane Dembélé', 'rating': 7.68},
#  827362: {'club': 'liverpool', 'name': 'Caoimhin Kelleher', 'rating': 7.65},
#  829932: {'club': 'atalanta', 'name': 'Cristian Romero', 'rating': 7.78},
#  839956: {'club': 'borussia-dortmund',
#   'name': 'Erling Braut Haaland',
#   'rating': 8.08},
#  84854: {'club': 'juventus', 'name': 'Alex Sandro', 'rating': 7.83},
#  885908: {'club': 'chelsea', 'name': 'Reece James', 'rating': 7.65},
#  8959: {'club': 'bayern-munchen', 'name': 'Manuel Neuer', 'rating': 7.84},
#  976364: {'club': 'dynamo-kyiv', 'name': 'Ruslan Neshcheret', 'rating': 9.7},
#  'id': 26502}

# %%
results
# Out:
# [{'accuratePassesPercentage': 90.91,
#   'assists': 0,
#   'goals': 0,
#   'player': {'id': 976364,
#    'name': 'Ruslan Neshcheret',
#    'slug': 'ruslan-neshcheret',
#    'userCount': 671},
#   'rating': 9.7,
#   'successfulDribbles': 0,
#   'tackles': 0,
#   'team': {'id': 3305,
#    'slug': 'dynamo-kyiv',
#    'teamColors': {'primary': '#52b030',
#     'secondary': '#52b030',
#     'text': '#ffffff'},
#    'type': 0,
#    'userCount': 0}},
#  {'accuratePassesPercentage': 85.71,
#   'assists': 0,
#   'goals': 0,
#   'player': {'id': 2069,
#    'name': 'Gianluigi Buffon',
#    'slug': 'gianluigi-buffon',
#    'userCount': 11449},
#   'rating': 8.5,
#   'successfulDribbles': 0,
#   'tackles': 0,
#   'team': {'id': 2687,
#    'slug': 'juventus',
#    'teamColors': {'primary': '#52b030',
#     'secondary': '#52b030',
#     'text': '#ffffff'},
#    'type': 0,
#    'userCount': 0}},
#  {'accuratePassesPercentage': 87.25,
#   'assists': 3,
#   'goals': 1,
#   'player': {'id': 259117,
#    'name': 'Joshua Kimmich',
#    'slug': 'joshua-kimmich',
#    'userCount': 10321},
#   'rating': 8.47,
#   'successfulDribbles': 2,
#   'tackles': 9,
#   'team': {'id': 2672,
#    'slug': 'bayern-munchen',
#    'teamColors': {'primary': '#52b030',
#     'secondary': '#52b030',
#     'text': '#ffffff'},
#    'type': 0,
#    'userCount': 0}},
#  {'accuratePassesPercentage': 89.38,
#   'assists': 2,
#   'goals': 3,
#   'player': {'id': 12994,
#    'name': 'Lionel Messi',
#    'slug': 'lionel-messi',
#    'userCount': 301771},
#   'rating': 8.45,
#   'successfulDribbles': 23,
#   'tackles': 3,
#   'team': {'id': 2817,
#    'slug': 'barcelona',
#    'teamColors': {'primary': '#52b030',
#     'secondary': '#52b030',
#     'text': '#ffffff'},
#    'type': 0,
#    'userCount': 0}},
#  {'accuratePassesPercentage': 85,
#   'assists': 4,
#   'goals': 0,
#   'player': {'id': 70996,
#    'name': 'Kevin De Bruyne',
#    'slug': 'kevin-de-bruyne',
#    'userCount': 68347},
#   'rating': 8.4,
#   'successfulDribbles': 1,
#   'tackles': 5,
#   'team': {'id': 17,
#    'slug': 'manchester-city',
#    'teamColors': {'primary': '#52b030',
#     'secondary': '#52b030',
#     'text': '#ffffff'},
#    'type': 0,
#    'userCount': 0}},
#  {'accuratePassesPercentage': 81.44,
#   'assists': 0,
#   'goals': 6,
#   'player': {'id': 124712,
#    'name': 'Neymar',
#    'slug': 'neymar',
#    'userCount': 180587},
#   'rating': 8.08,
#   'successfulDribbles': 21,
#   'tackles': 3,
#   'team': {'id': 1644,
#    'slug': 'paris-saint-germain',
#    'teamColors': {'primary': '#52b030',
#     'secondary': '#52b030',
#     'text': '#ffffff'},
#    'type': 0,
#    'userCount': 0}},
#  {'accuratePassesPercentage': 74.63,
#   'assists': 0,
#   'goals': 6,
#   'player': {'id': 839956,
#    'name': 'Erling Braut Haaland',
#    'slug': 'erling-braut-haaland',
#    'userCount': 70181},
#   'rating': 8.08,
#   'successfulDribbles': 6,
#   'tackles': 0,
#   'team': {'id': 2673,
#    'slug': 'borussia-dortmund',
#    'teamColors': {'primary': '#52b030',
#     'secondary': '#52b030',
#     'text': '#ffffff'},
#    'type': 0,
#    'userCount': 0}},
#  {'accuratePassesPercentage': 81.13,
#   'assists': 1,
#   'goals': 5,
#   'player': {'id': 45923,
#    'name': 'Ciro Immobile',
#    'slug': 'ciro-immobile',
#    'userCount': 14734},
#   'rating': 7.98,
#   'successfulDribbles': 4,
#   'tackles': 1,
#   'team': {'id': 2699,
#    'slug': 'lazio',
#    'teamColors': {'primary': '#52b030',
#     'secondary': '#52b030',
#     'text': '#ffffff'},
#    'type': 0,
#    'userCount': 0}},
#  {'accuratePassesPercentage': 72.52,
#   'assists': 1,
#   'goals': 6,
#   'player': {'id': 125407,
#    'name': 'Álvaro Morata',
#    'slug': 'alvaro-morata',
#    'userCount': 14787},
#   'rating': 7.92,
#   'successfulDribbles': 9,
#   'tackles': 4,
#   'team': {'id': 2687,
#    'slug': 'juventus',
#    'teamColors': {'primary': '#52b030',
#     'secondary': '#52b030',
#     'text': '#ffffff'},
#    'type': 0,
#    'userCount': 0}},
#  {'accuratePassesPercentage': 85.71,
#   'assists': 0,
#   'goals': 0,
#   'player': {'id': 8959,
#    'name': 'Manuel Neuer',
#    'slug': 'manuel-neuer',
#    'userCount': 14516},
#   'rating': 7.84,
#   'successfulDribbles': 0,
#   'tackles': 0,
#   'team': {'id': 2672,
#    'slug': 'bayern-munchen',
#    'teamColors': {'primary': '#52b030',
#     'secondary': '#52b030',
#     'text': '#ffffff'},
#    'type': 0,
#    'userCount': 0}},
#  {'accuratePassesPercentage': 85.34,
#   'assists': 1,
#   'goals': 0,
#   'player': {'id': 84854,
#    'name': 'Alex Sandro',
#    'slug': 'alex-sandro',
#    'userCount': 5886},
#   'rating': 7.83,
#   'successfulDribbles': 5,
#   'tackles': 9,
#   'team': {'id': 2687,
#    'slug': 'juventus',
#    'teamColors': {'primary': '#52b030',
#     'secondary': '#52b030',
#     'text': '#ffffff'},
#    'type': 0,
#    'userCount': 0}},
#  {'accuratePassesPercentage': 73.97,
#   'assists': 1,
#   'goals': 4,
#   'player': {'id': 288205,
#    'name': 'Bruno Fernandes',
#    'slug': 'bruno-fernandes',
#    'userCount': 44331},
#   'rating': 7.8,
#   'successfulDribbles': 3,
#   'tackles': 9,
#   'team': {'id': 35,
#    'slug': 'manchester-united',
#    'teamColors': {'primary': '#52b030',
#     'secondary': '#52b030',
#     'text': '#ffffff'},
#    'type': 0,
#    'userCount': 0}},
#  {'accuratePassesPercentage': 62.07,
#   'assists': 0,
#   'goals': 0,
#   'player': {'id': 50539,
#    'name': 'Adrián',
#    'slug': 'adrian',
#    'userCount': 1877},
#   'rating': 7.8,
#   'successfulDribbles': 0,
#   'tackles': 0,
#   'team': {'id': 44,
#    'slug': 'liverpool',
#    'teamColors': {'primary': '#52b030',
#     'secondary': '#52b030',
#     'text': '#ffffff'},
#    'type': 0,
#    'userCount': 0}},
#  {'accuratePassesPercentage': 84.51,
#   'assists': 1,
#   'goals': 1,
#   'player': {'id': 829932,
#    'name': 'Cristian Romero',
#    'slug': 'cristian-romero',
#    'userCount': 1562},
#   'rating': 7.78,
#   'successfulDribbles': 1,
#   'tackles': 12,
#   'team': {'id': 2686,
#    'slug': 'atalanta',
#    'teamColors': {'primary': '#52b030',
#     'secondary': '#52b030',
#     'text': '#ffffff'},
#    'type': 0,
#    'userCount': 0}},
#  {'accuratePassesPercentage': 83.52,
#   'assists': 1,
#   'goals': 0,
#   'player': {'id': 578560,
#    'name': 'Marcos Acuña',
#    'slug': 'marcos-acuna',
#    'userCount': 1208},
#   'rating': 7.7,
#   'successfulDribbles': 7,
#   'tackles': 7,
#   'team': {'id': 2833,
#    'slug': 'sevilla',
#    'teamColors': {'primary': '#52b030',
#     'secondary': '#52b030',
#     'text': '#ffffff'},
#    'type': 0,
#    'userCount': 0}},
#  {'accuratePassesPercentage': 83.06,
#   'assists': 2,
#   'goals': 3,
#   'player': {'id': 818244,
#    'name': 'Ousmane Dembélé',
#    'slug': 'ousmane-dembele',
#    'userCount': 44118},
#   'rating': 7.68,
#   'successfulDribbles': 16,
#   'tackles': 2,
#   'team': {'id': 2817,
#    'slug': 'barcelona',
#    'teamColors': {'primary': '#52b030',
#     'secondary': '#52b030',
#     'text': '#ffffff'},
#    'type': 0,
#    'userCount': 0}},
#  {'accuratePassesPercentage': 86.14,
#   'assists': 1,
#   'goals': 0,
#   'player': {'id': 885908,
#    'name': 'Reece James',
#    'slug': 'reece-james',
#    'userCount': 5302},
#   'rating': 7.65,
#   'successfulDribbles': 1,
#   'tackles': 7,
#   'team': {'id': 38,
#    'slug': 'chelsea',
#    'teamColors': {'primary': '#52b030',
#     'secondary': '#52b030',
#     'text': '#ffffff'},
#    'type': 0,
#    'userCount': 0}},
#  {'accuratePassesPercentage': 67.09,
#   'assists': 0,
#   'goals': 0,
#   'player': {'id': 827362,
#    'name': 'Caoimhin Kelleher',
#    'slug': 'caoimhin-kelleher',
#    'userCount': 1226},
#   'rating': 7.65,
#   'successfulDribbles': 0,
#   'tackles': 0,
#   'team': {'id': 44,
#    'slug': 'liverpool',
#    'teamColors': {'primary': '#52b030',
#     'secondary': '#52b030',
#     'text': '#ffffff'},
#    'type': 0,
#    'userCount': 0}},
#  {'accuratePassesPercentage': 77.37,
#   'assists': 3,
#   'goals': 5,
#   'player': {'id': 192308,
#    'name': 'Alassane Pléa',
#    'slug': 'alassane-plea',
#    'userCount': 2887},
#   'rating': 7.63,
#   'successfulDribbles': 4,
#   'tackles': 2,
#   'team': {'id': 2527,
#    'slug': 'borussia-mgladbach',
#    'teamColors': {'primary': '#52b030',
#     'secondary': '#52b030',
#     'text': '#ffffff'},
#    'type': 0,
#    'userCount': 0}},
#  {'accuratePassesPercentage': 94.04,
#   'assists': 1,
#   'goals': 0,
#   'player': {'id': 26502,
#    'name': 'Toni Kroos',
#    'slug': 'toni-kroos',
#    'userCount': 35425},
#   'rating': 7.63,
#   'successfulDribbles': 1,
#   'tackles': 7,
#   'team': {'id': 2829,
#    'slug': 'real-madrid',
#    'teamColors': {'primary': '#52b030',
#     'secondary': '#52b030',
#     'text': '#ffffff'},
#    'type': 0,
#    'userCount': 0}}]
